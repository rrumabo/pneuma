# %%
from src.runner import solve_fixed_step
from src.models.sw_adapter import rhs, make_initial_sw
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.runner import solve_fixed_step
#       2 from src.models.sw_adapter import rhs, make_initial_sw
#
# ModuleNotFoundError: No module named 'src.runner'
